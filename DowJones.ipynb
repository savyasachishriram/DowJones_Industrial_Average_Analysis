# %%
import pandas as pd
import yfinance as yf
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///Stockdata.db")

# %%
dow = pd.read_html("https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average")
dow
# Out:
# [                                                   0  \
#  0  Historical logarithmic graph of the DJIA from ...
#  1                                         Foundation
#  2                                           Operator
#  3                                          Exchanges
#  4                                     Trading symbol
#  5                                       Constituents
#  6                                               Type
#  7                                         Market cap
#  8                                   Weighting method
#  9                                            Website
#
#                                                     1
#  0  Historical logarithmic graph of the DJIA from ...
#  1  February 16, 1885; 138 years ago (as DJA)[1] M...
#  2                              S&P Dow Jones Indices
#  3                      New York Stock ExchangeNasdaq
#  4                                  ^DJI$INDU.DJIDJIA
# ...

# %%
dow[1]
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                     Disney     NYSE    DIS  Broadcasting and entertainment
# 10                       Dow     NYSE    DOW               Chemical industry
# ...

# %%
symbols =dow[1].Symbol.to_list()

# %%
symbols
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
infos = []

for symbol in symbols:
    inf = yf.Ticker(symbol).info
    if symbol=='CAT':
        inf = yf.Ticker('CAT').info
    infos.append(inf)
    print(symbol)
# Out:
# MMM
# AXP
# AMGN
# AAPL
# BA
# CAT
# CVX
# CSCO
# KO
# DIS
# DOW
# GS
# HD
# HON
# IBM
# INTC
# JNJ
# JPM
# MCD
# MRK
# MSFT
# NKE
# PG
# CRM
# TRV
# UNH
# VZ
# V
# WBA
# WMT

# %%
inf = yf.Ticker('CAT').info
inf
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 279.15,
#  'open': 279.06,
#  'dayLow': 278.81,
#  'dayHigh': 280.71,
#  'regularMarketPreviousClose': 279.15,
#  'regularMarketOpen': 279.06,
#  'regularMarketDayLow': 278.81,
#  'regularMarketDayHigh': 280.71,
#  'trailingPE': 20.72781,
#  'forwardPE': 13.382998,
#  'volume': 79913,
#  'regularMarketVolume': 79913,
#  'averageVolume': 2623038,
#  'averageVolume10days': 2219010,
#  'averageDailyVolume10Day': 2219010,
#  'bid': 278.66,
#  'ask': 279.05,
#  'bidSize': 1300,
#  'askSize': 800,
#  'marketCap': 144700801024,
#  'fiftyTwoWeekLow': 160.6,
#  'fiftyTwoWeekHigh': 293.88,
#  'fiftyDayAverage': 272.1608,
#  'twoHundredDayAverage': 242.79875,
#  'trailingAnnualDividendRate': 3.6,
#  'trailingAnnualDividendYield': 0.012896292,
#  'currency': 'USD',
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'CAT',
#  'underlyingSymbol': 'CAT',
#  'shortName': 'Caterpillar, Inc.',
#  'longName': 'Caterpillar Inc.',
# ...

# %%
infos.append(inf)

# %%
df = pd.DataFrame(infos)
df
# Out:
#                           address1           city state         zip  \
# 0                        3M Center     Saint Paul    MN  55144-1000
# 1                 200 Vesey Street       New York    NY       10285
# 2           One Amgen Center Drive  Thousand Oaks    CA  91320-1799
# 3               One Apple Park Way      Cupertino    CA       95014
# 4            929 Long Bridge Drive      Arlington    VA       22202
# 5                              NaN            NaN   NaN         NaN
# 6       6001 Bollinger Canyon Road      San Ramon    CA  94583-2324
# 7            170 West Tasman Drive       San Jose    CA  95134-1706
# 8              One Coca-Cola Plaza        Atlanta    GA       30313
# 9     500 South Buena Vista Street        Burbank    CA       91521
# 10               2211 H.H. Dow Way        Midland    MI       48674
# 11                 200 West Street       New York    NY       10282
# 12           2455 Paces Ferry Road        Atlanta    GA       30339
# ...

# %%
df
# Out:
#                           address1           city state         zip  \
# 0                        3M Center     Saint Paul    MN  55144-1000
# 1                 200 Vesey Street       New York    NY       10285
# 2           One Amgen Center Drive  Thousand Oaks    CA  91320-1799
# 3               One Apple Park Way      Cupertino    CA       95014
# 4            929 Long Bridge Drive      Arlington    VA       22202
# 5                              NaN            NaN   NaN         NaN
# 6       6001 Bollinger Canyon Road      San Ramon    CA  94583-2324
# 7            170 West Tasman Drive       San Jose    CA  95134-1706
# 8              One Coca-Cola Plaza        Atlanta    GA       30313
# 9     500 South Buena Vista Street        Burbank    CA       91521
# 10               2211 H.H. Dow Way        Midland    MI       48674
# 11                 200 West Street       New York    NY       10282
# 12           2455 Paces Ferry Road        Atlanta    GA       30339
# ...

# %%
df = df.drop(columns="companyOfficers")

# %%
obj = yf.Ticker("NKE") #creating ticker object

# %%
obj.info
# Out:
# {'address1': 'One Bowerman Drive',
#  'city': 'Beaverton',
#  'state': 'OR',
#  'zip': '97005-6453',
#  'country': 'United States',
#  'phone': '503 671 6453',
#  'website': 'https://www.nike.com',
#  'industry': 'Footwear & Accessories',
#  'industryDisp': 'Footwear & Accessories',
#  'sector': 'Consumer Cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
df.to_sql("Fundamentals",engine, index=False, if_exists = "replace")
# Out:
# 31

# %%
pd.read_sql("Fundamentals",engine)
# Out:
#                           address1           city state         zip  \
# 0                        3M Center     Saint Paul    MN  55144-1000
# 1                 200 Vesey Street       New York    NY       10285
# 2           One Amgen Center Drive  Thousand Oaks    CA  91320-1799
# 3               One Apple Park Way      Cupertino    CA       95014
# 4            929 Long Bridge Drive      Arlington    VA       22202
# 5                             None           None  None        None
# 6       6001 Bollinger Canyon Road      San Ramon    CA  94583-2324
# 7            170 West Tasman Drive       San Jose    CA  95134-1706
# 8              One Coca-Cola Plaza        Atlanta    GA       30313
# 9     500 South Buena Vista Street        Burbank    CA       91521
# 10               2211 H.H. Dow Way        Midland    MI       48674
# 11                 200 West Street       New York    NY       10282
# 12           2455 Paces Ferry Road        Atlanta    GA       30339
# ...

# %%
df.dividendYield
# Out:
# 0     0.0594
# 1     0.0147
# 2     0.0327
# 3     0.0055
# 4        NaN
# 5        NaN
# 6     0.0363
# 7     0.0278
# 8     0.0318
# 9        NaN
# 10    0.0518
# 11    0.0321
# 12    0.0260
# 13    0.0213
# 14    0.0455
# 15    0.0129
# 16    0.0295
# 17    0.0269
# 18    0.0219
# 19    0.0272
# 20    0.0082
# 21    0.0141
# 22    0.0245
# 23       NaN
# 24    0.0243
# 25    0.0145
# 26    0.0787
# 27    0.0075
# 28    0.0856
# 29    0.0138
# 30       NaN
# Name: dividendYield, dtype: float64
